in_net_pow_ele  nb_prod_act  net_margin  num_years_antig  \
# 3927                29.76            1      136.40                6
# 8142                14.64            1      141.16                3
# 14514               24.72            1      332.25                3
# 4464                 0.72            2      607.79                5
# 4381                 6.18            2      269.94               10
# 597                 18.76            1      116.09               11
# 2901                19.56            1       93.09                5
# 1826                27.95            4      414.81                3
# 2912                33.78            1      440.02                3
# 13317                6.45            1      225.49                6
#
#                               origin_up  pow_max  churn
# 3927   kamkkxfxxuwbdslkwifmmcsiusiuosws   14.500      0
# 8142   kamkkxfxxuwbdslkwifmmcsiusiuosws   13.800      0
# 14514  lxidpiddsbxsbosboudacockeimpuepw   16.500      0
# 4464   ldkssxwpmemidmecebumciepifcamkci   16.500      0
# 4381   ldkssxwpmemidmecebumciepifcamkci   13.200      0
# 597    ldkssxwpmemidmecebumciepifcamkci   15.001      0
# 2901   lxidpiddsbxsbosboudacockeimpuepw   13.850      0
# 1826   lxidpiddsbxsbosboudacockeimpuepw   10.392      0
# 2912   lxidpiddsbxsbosboudacockeimpuepw   54.000      0
# 13317  kamkkxfxxuwbdslkwifmmcsiusiuosws   13.856      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  object
#  1   channel_sales                   14606 non-null  object
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  object
#  6   date_end                        14606 non-null  object
#  7   date_modif_prod                 14606 non-null  object
#  8   date_renewal                    14606 non-null  object
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
#  11  forecast_discount_energy        14606 non-null  float64
#  12  forecast_meter_rent_12m         14606 non-null  float64
#  13  forecast_price_energy_off_peak  14606 non-null  float64
#  14  forecast_price_energy_peak      14606 non-null  float64
#  15  forecast_price_pow_off_peak     14606 non-null  float64
#  16  has_gas                         14606 non-null  object
#  17  imp_cons                        14606 non-null  float64
#  18  margin_gross_pow_ele            14606 non-null  float64
#  19  margin_net_pow_ele              14606 non-null  float64
#  20  nb_prod_act                     14606 non-null  int64
#  21  net_margin                      14606 non-null  float64
#  22  num_years_antig                 14606 non-null  int64
#  23  origin_up                       14606 non-null  object
#  24  pow_max                         14606 non-null  float64
#  25  churn                           14606 non-null  int64
# dtypes: float64(11), int64(7), object(8)
# memory usage: 2.9+ MB

# %%
df.describe().T
# Out:
#                                   count           mean            std  min  \
# cons_12m                        14606.0  159220.286252  573465.264198  0.0
# cons_gas_12m                    14606.0   28092.375325  162973.059057  0.0
# cons_last_month                 14606.0   16090.269752   64364.196422  0.0
# forecast_cons_12m               14606.0    1868.614880    2387.571531  0.0
# forecast_cons_year              14606.0    1399.762906    3247.786255  0.0
# forecast_discount_energy        14606.0       0.966726       5.108289  0.0
# forecast_meter_rent_12m         14606.0      63.086871      66.165783  0.0
# forecast_price_energy_off_peak  14606.0       0.137283       0.024623  0.0
# forecast_price_energy_peak      14606.0       0.050491       0.049037  0.0
# forecast_price_pow_off_peak     14606.0      43.130056       4.485988  0.0
# imp_cons                        14606.0     152.786896     341.369366  0.0
# margin_gross_pow_ele            14606.0      24.565121      20.231172  0.0
# margin_net_pow_ele              14606.0      24.562517      20.230280  0.0
# nb_prod_act                     14606.0       1.292346       0.709774  1.0
# net_margin                      14606.0     189.264522     311.798130  0.0
# num_years_antig                 14606.0       4.997809       1.611749  1.0
# pow_max                         14606.0      18.135136      13.534743  3.3
# churn                           14606.0       0.097152       0.296175  0.0
#
#                                         25%           50%           75%  \
# cons_12m                        5674.750000  14115.500000  40763.750000
# cons_gas_12m                       0.000000      0.000000      0.000000
# cons_last_month                    0.000000    792.500000   3383.000000
# forecast_cons_12m                494.995000   1112.875000   2401.790000
# forecast_cons_year                 0.000000    314.000000   1745.750000
# forecast_discount_energy           0.000000      0.000000      0.000000
# forecast_meter_rent_12m           16.180000     18.795000    131.030000
# forecast_price_energy_off_peak     0.116340      0.143166      0.146348
# forecast_price_energy_peak         0.000000      0.084138      0.098837
# forecast_price_pow_off_peak       40.606701     44.311378     44.311378
# imp_cons                           0.000000     37.395000    193.980000
# margin_gross_pow_ele              14.280000     21.640000     29.880000
# margin_net_pow_ele                14.280000     21.640000     29.880000
# nb_prod_act                        1.000000      1.000000      1.000000
# net_margin                        50.712500    112.530000    243.097500
# num_years_antig                    4.000000      5.000000      6.000000
# pow_max                           12.500000     13.856000     19.172500
# churn                              0.000000      0.000000      0.000000
#
#                                          max
# cons_12m                        6.207104e+06
# cons_gas_12m                    4.154590e+06
# cons_last_month                 7.712030e+05
# forecast_cons_12m               8.290283e+04
# forecast_cons_year              1.753750e+05
# forecast_discount_energy        3.000000e+01
# forecast_meter_rent_12m         5.993100e+02
# forecast_price_energy_off_peak  2.739630e-01
# forecast_price_energy_peak      1.959750e-01
# forecast_price_pow_off_peak     5.926638e+01
# imp_cons                        1.504279e+04
# margin_gross_pow_ele            3.746400e+02
# margin_net_pow_ele              3.746400e+02
# nb_prod_act                     3.200000e+01
# net_margin                      2.457065e+04
# num_years_antig                 1.300000e+01
# pow_max                         3.200000e+02
# churn                           1.000000e+00

# %%
df.isnull().sum()
# Out:
# id                                0
# channel_sales                     0
# cons_12m                          0
# cons_gas_12m                      0
# cons_last_month                   0
# date_activ                        0
# date_end                          0
# date_modif_prod                   0
# date_renewal                      0
# forecast_cons_12m                 0
# forecast_cons_year                0
# forecast_discount_energy          0
# forecast_meter_rent_12m           0
# forecast_price_energy_off_peak    0
# forecast_price_energy_peak        0
# forecast_price_pow_off_peak       0
# has_gas                           0
# imp_cons                          0
# margin_gross_pow_ele              0
# margin_net_pow_ele                0
# nb_prod_act                       0
# net_margin                        0
# num_years_antig                   0
# origin_up                         0
# pow_max                           0
# churn                             0
# dtype: int64

# %%
df.isna().sum()
# Out:
# id                                0
# channel_sales                     0
# cons_12m                          0
# cons_gas_12m                      0
# cons_last_month                   0
# date_activ                        0
# date_end                          0
# date_modif_prod                   0
# date_renewal                      0
# forecast_cons_12m                 0
# forecast_cons_year                0
# forecast_discount_energy          0
# forecast_meter_rent_12m           0
# forecast_price_energy_off_peak    0
# forecast_price_energy_peak        0
# forecast_price_pow_off_peak       0
# has_gas                           0
# imp_cons                          0
# margin_gross_pow_ele              0
# margin_net_pow_ele                0
# nb_prod_act                       0
# net_margin                        0
# num_years_antig                   0
# origin_up                         0
# pow_max                           0
# churn                             0
# dtype: int64

# %%
df.date_activ = pd.to_datetime(df.date_activ)
df.date_activ
# Out:
# 0       2013-06-15
# 1       2009-08-21
# 2       2010-04-16
# 3       2010-03-30
# 4       2010-01-13
#            ...
# 14601   2012-05-24
# 14602   2012-08-27
# 14603   2012-02-08
# 14604   2012-08-30
# 14605   2009-12-18
# Name: date_activ, Length: 14606, dtype: datetime64[ns]

# %%
df.date_end = pd.to_datetime(df.date_end)
df.date_end
# Out:
# 0       2016-06-15
# 1       2016-08-30
# 2       2016-04-16
# 3       2016-03-30
# 4       2016-03-07
#            ...
# 14601   2016-05-08
# 14602   2016-08-27
# 14603   2016-02-07
# 14604   2016-08-30
# 14605   2016-12-17
# Name: date_end, Length: 14606, dtype: datetime64[ns]

# %%
df.date_modif_prod = pd.to_datetime(df.date_modif_prod)
df.date_renewal = pd.to_datetime(df.date_renewal)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  object
#  1   channel_sales                   14606 non-null  object
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  datetime64[ns]
#  6   date_end                        14606 non-null  datetime64[ns]
#  7   date_modif_prod                 14606 non-null  datetime64[ns]
#  8   date_renewal                    14606 non-null  datetime64[ns]
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
#  11  forecast_discount_energy        14606 non-null  float64
#  12  forecast_meter_rent_12m         14606 non-null  float64
#  13  forecast_price_energy_off_peak  14606 non-null  float64
#  14  forecast_price_energy_peak      14606 non-null  float64
#  15  forecast_price_pow_off_peak     14606 non-null  float64
#  16  has_gas                         14606 non-null  object
#  17  imp_cons                        14606 non-null  float64
#  18  margin_gross_pow_ele            14606 non-null  float64
#  19  margin_net_pow_ele              14606 non-null  float64
#  20  nb_prod_act                     14606 non-null  int64
#  21  net_margin                      14606 non-null  float64
#  22  num_years_antig                 14606 non-null  int64
#  23  origin_up                       14606 non-null  object
#  24  pow_max                         14606 non-null  float64
#  25  churn                           14606 non-null  int64
# dtypes: datetime64[ns](4), float64(11), int64(7), object(4)
# memory usage: 2.9+ MB

# %%
numerical_col = [i for i in df.columns if df[i].dtype == 'float64' or df[i].dtype == 'int64']

 
categorical_col = [i for i in df.columns if df[i].dtype =='O']

# %%
len(numerical_col) , len(categorical_col)
# Out:
# (18, 4)

# %%
categorical_col
# Out:
# ['id', 'channel_sales', 'has_gas', 'origin_up']

# %%
numerical_col
# Out:
# ['cons_12m',
#  'cons_gas_12m',
#  'cons_last_month',
#  'forecast_cons_12m',
#  'forecast_cons_year',
#  'forecast_discount_energy',
#  'forecast_meter_rent_12m',
#  'forecast_price_energy_off_peak',
#  'forecast_price_energy_peak',
#  'forecast_price_pow_off_peak',
#  'imp_cons',
#  'margin_gross_pow_ele',
#  'margin_net_pow_ele',
#  'nb_prod_act',
#  'net_margin',
#  'num_years_antig',
#  'pow_max',
#  'churn']

# %%
df.origin_up.value_counts()
# Out:
# origin_up
# lxidpiddsbxsbosboudacockeimpuepw    7097
# kamkkxfxxuwbdslkwifmmcsiusiuosws    4294
# ldkssxwpmemidmecebumciepifcamkci    3148
# MISSING                               64
# usapbepcfoloekilkwsdiboslwaxobdp       2
# ewxeelcelemmiwuafmddpobolfuxioce       1
# Name: count, dtype: int64

# %%
'''Exploratory Analysis'''
# Out:
# 'Exploratory Analysis'

# %%
print(df.columns)

print()

print("Total number of columns : ",len(df.columns))
# Out:
# Index(['id', 'channel_sales', 'cons_12m', 'cons_gas_12m', 'cons_last_month',
#        'date_activ', 'date_end', 'date_modif_prod', 'date_renewal',
#        'forecast_cons_12m', 'forecast_cons_year', 'forecast_discount_energy',
#        'forecast_meter_rent_12m', 'forecast_price_energy_off_peak',
#        'forecast_price_energy_peak', 'forecast_price_pow_off_peak', 'has_gas',
#        'imp_cons', 'margin_gross_pow_ele', 'margin_net_pow_ele', 'nb_prod_act',
#        'net_margin', 'num_years_antig', 'origin_up', 'pow_max', 'churn'],
#       dtype='object')
#
# Total number of columns :  26

# %%
'''Univariate Analysis'''

'''Categorical Data'''
# Out:
# 'Categorical Data'

# %%
nominal_data = [i for i in df[categorical_col] if df[i].nunique()<10]

nominal_data
# Out:
# ['channel_sales', 'has_gas', 'origin_up']

# %%
'''Column: channel_sales'''
# Out:
# 'Column: channel_sales'

# %%
df[['channel_sales']].head()
# Out:
#                       channel_sales
# 0  foosdfpfkusacimwkcsosbicdxkicaua
# 1                           MISSING
# 2  foosdfpfkusacimwkcsosbicdxkicaua
# 3  lmkebamcaaclubfxadlmueccxoimlema
# 4                           MISSING

# %%
df.channel_sales.unique()
# Out:
# array(['foosdfpfkusacimwkcsosbicdxkicaua', 'MISSING',
#        'lmkebamcaaclubfxadlmueccxoimlema',
#        'usilxuppasemubllopkaafesmlibmsdf',
#        'ewpakwlliwisiwduibdlfmalxowmwpci',
#        'epumfxlbckeskwekxbiuasklxalciiuu',
#        'sddiedcslfslkckwlfkdpoeeailfpeds',
#        'fixdbufsefwooaasfcxdxadsiekoceaa'], dtype=object)

# %%
df.channel_sales.value_counts()
# Out:
# channel_sales
# foosdfpfkusacimwkcsosbicdxkicaua    6754
# MISSING                             3725
# lmkebamcaaclubfxadlmueccxoimlema    1843
# usilxuppasemubllopkaafesmlibmsdf    1375
# ewpakwlliwisiwduibdlfmalxowmwpci     893
# sddiedcslfslkckwlfkdpoeeailfpeds      11
# epumfxlbckeskwekxbiuasklxalciiuu       3
# fixdbufsefwooaasfcxdxadsiekoceaa       2
# Name: count, dtype: int64

# %%
print(f'Total No. of uniue categories: {df.channel_sales.nunique()}')
# Out:
# Total No. of uniue categories: 8

# %%
df.channel_sales.value_counts().plot(kind='pie' , autopct='%1.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df.channel_sales.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='channel_sales'>

# %%
df.channel_sales.describe(include='all')
# Out:
# count                                14606
# unique                                   8
# top       foosdfpfkusacimwkcsosbicdxkicaua
# freq                                  6754
# Name: channel_sales, dtype: object

# %%
df.has_gas.value_counts()
# Out:
# has_gas
# f    11955
# t     2651
# Name: count, dtype: int64

# %%
df.has_gas.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='has_gas'>

# %%
df[['origin_up']].head()
# Out:
#                           origin_up
# 0  lxidpiddsbxsbosboudacockeimpuepw
# 1  kamkkxfxxuwbdslkwifmmcsiusiuosws
# 2  kamkkxfxxuwbdslkwifmmcsiusiuosws
# 3  kamkkxfxxuwbdslkwifmmcsiusiuosws
# 4  kamkkxfxxuwbdslkwifmmcsiusiuosws

# %%
df.origin_up.value_counts()
# Out:
# origin_up
# lxidpiddsbxsbosboudacockeimpuepw    7097
# kamkkxfxxuwbdslkwifmmcsiusiuosws    4294
# ldkssxwpmemidmecebumciepifcamkci    3148
# MISSING                               64
# usapbepcfoloekilkwsdiboslwaxobdp       2
# ewxeelcelemmiwuafmddpobolfuxioce       1
# Name: count, dtype: int64

# %%
df.origin_up.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='origin_up'>

# %%
'''Numerical Analysis'''
# Out:
# 'Numerical Analysis'

# %%
df[['cons_12m','cons_gas_12m','cons_last_month','forecast_cons_12m','forecast_cons_year',
    'forecast_discount_energy']].hist(figsize=(12, 8), bins=20)
plt.show()

# %%
sns.kdeplot(data=df.forecast_price_energy_peak, fill=True, common_norm=False, palette='husl')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16012\1287239694.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data=df.forecast_price_energy_peak, fill=True, common_norm=False, palette='husl')

# %%
sns.kdeplot(data=df.forecast_meter_rent_12m, fill=True, common_norm=False, palette='husl')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16012\822765758.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data=df.forecast_meter_rent_12m, fill=True, common_norm=False, palette='husl')

# %%
sns.kdeplot(data=df.num_years_antig, fill=True, common_norm=False, palette='husl')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16012\2694013979.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data=df.num_years_antig, fill=True, common_norm=False, palette='husl')

# %%
df.net_margin.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
'''Bivariate Analysis'''
# Out:
# 'Bivariate Analysis'

# %%
'''Categorical columns'''
# Out:
# 'Categorical columns'

# %%
sns.countplot(x='channel_sales', hue='has_gas', data=df)
plt.show()

# %%
sns.countplot(x='channel_sales', hue='origin_up', data=df)
plt.show()

# %%
from scipy.stats import chi2_contingency

contingency_table = pd.crosstab(df['channel_sales'], df['has_gas'])
chi2, p, _, _ = chi2_contingency(contingency_table)
print(f"Chi-square: {chi2}\nP-value: {p}")
# Out:
# Chi-square: 48.65572391262786
# P-value: 2.6500113838615192e-08

# %%
from scipy.stats import chi2_contingency

contingency_table = pd.crosstab(df['channel_sales'], df['origin_up'])
chi2, p, _, _ = chi2_contingency(contingency_table)
print(f"Chi-square: {chi2}\nP-value: {p}")
# Out:
# Chi-square: 4738.659329821703
# P-value: 0.0

# %%
from scipy.stats import chi2_contingency

contingency_table = pd.crosstab(df['has_gas'], df['origin_up'])
chi2, p, _, _ = chi2_contingency(contingency_table)
print(f"Chi-square: {chi2}\nP-value: {p}")
# Out:
# Chi-square: 5.075428757277808
# P-value: 0.4067443483055234

# %%
'''Numerical Analysis'''
# Out:
# 'Numerical Analysis'

# %%
correlation = df['forecast_price_energy_peak'].corr(df['churn'])
print(f"Correlation coefficient: {correlation}")
# Out:
# Correlation coefficient: 0.02931513743797397

# %%
correlation = df['cons_12m'].corr(df['churn'])
print(f"Correlation coefficient: {correlation}")
# Out:
# Correlation coefficient: -0.04596783240669078

# %%
correlation = df['cons_gas_12m'].corr(df['churn'])
print(f"Correlation coefficient: {correlation}")
# Out:
# Correlation coefficient: -0.0379567492876476

# %%
correlation = df['cons_last_month'].corr(df['churn'])
print(f"Correlation coefficient: {correlation}")
# Out:
# Correlation coefficient: -0.04528429556494654

# %%
correlation = df['pow_max'].corr(df['churn'])
print(f"Correlation coefficient: {correlation}")
# Out:
# Correlation coefficient: 0.03036178084757641

# %%
import statsmodels.api as sm
X = sm.add_constant(df['margin_gross_pow_ele'])
model = sm.OLS(df['churn'], X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  churn   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     135.1
# Date:                Sun, 04 Feb 2024   Prob (F-statistic):           4.39e-31
# Time:                        10:35:15   Log-Likelihood:                -2884.6
# No. Observations:               14606   AIC:                             5773.
# Df Residuals:                   14604   BIC:                             5788.
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0627      0.004     16.346      0.000       0.055       0.070
# margin_gross_pow_ele     0.0014      0.000     11.621      0.000       0.001       0.002
# ==============================================================================
# Omnibus:                     7594.474   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            34879.574
# Skew:                           2.686   Prob(JB):                         0.00
# Kurtosis:                       8.335   Cond. No.                         50.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.api as sm
X = sm.add_constant(df['cons_last_month'])
model = sm.OLS(df['churn'], X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  churn   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     30.01
# Date:                Sun, 04 Feb 2024   Prob (F-statistic):           4.37e-08
# Time:                        10:36:53   Log-Likelihood:                -2936.9
# No. Observations:               14606   AIC:                             5878.
# Df Residuals:                   14604   BIC:                             5893.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.1005      0.003     39.826      0.000       0.096       0.105
# cons_last_month -2.084e-07    3.8e-08     -5.478      0.000   -2.83e-07   -1.34e-07
# ==============================================================================
# Omnibus:                     7658.624   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            35434.827
# Skew:                           2.711   Prob(JB):                         0.00
# Kurtosis:                       8.369   Cond. No.                     6.84e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.84e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
import seaborn as sns
correlation_matrix = df[['cons_12m','cons_gas_12m', 'cons_last_month','forecast_cons_12m', 
'forecast_cons_year', 'forecast_discount_energy']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
correlation_matrix = df[['forecast_meter_rent_12m','forecast_price_energy_off_peak','forecast_price_energy_peak', 
                     'forecast_price_pow_off_peak','imp_cons','margin_gross_pow_ele']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
correlation_matrix = df[['margin_net_pow_ele','nb_prod_act','net_margin','num_years_antig','pow_max','churn']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()
